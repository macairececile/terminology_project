# %% [markdown]
# # Terminology - Project

# %% [markdown]
# Authors: Cécile MACAIRE & Ludivine ROBERT

# %% [markdown]
# ## Librairies

# %%
import pandas as pd
import spacy
spacy_nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# # Code

# %%
    "    return df"
